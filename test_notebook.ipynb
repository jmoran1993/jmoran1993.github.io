# %%
import sys
sys.path.append("../python")

from hubbard_dimer import *

# %%
# %time dimer = hubbard_dimer()
# Out:
# CPU times: user 34.5 s, sys: 138 ms, total: 34.7 s
# Wall time: 34.7 s

# %%
dimer.evaluate11(1,0,1,1,3,1,0)
# Out:
# (-2.7645245142508741-3.7247757579901339j)

# %%
import hubbard_atom as atom
#import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['Polygon', 'cosh', 'poly', 'sign', 'colors', 'flatten', 'conjugate', 'diff', 'Circle', 'tan', 'roots', 'plot', 'eye', 'trace', 'floor', 'diag', 'invert', 'var', 'nan', 'sqrt', 'source', 'add', 'take', 'prod', 'trunc', 'plotting', 'product', 'power', 'multinomial', 'transpose', 'test', 'beta', 'ones', 'sinh', 'vectorize', 'mod', 'cos', 'seterr', 'tanh', 'det', 'pi', 'sin', 'binomial', 'solve', 'log', 'exp', 'reshape', 'gamma', 'interactive']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
beta = 3 
U =1.2
mu = 0.48
t=0.5

# %%
# %time atom.plotFig(0,U,beta,mu,0,-6,6,-6,6,500,1.0)
# Out:
# CPU times: user 501 ms, sys: 76 ms, total: 577 ms
# Wall time: 577 ms

# %%
# %time dimer.plotFig11(0,U,t,beta,mu,0,-6,6,-6,6,500,1.0)
# Out:
# CPU times: user 11.1 s, sys: 520 ms, total: 11.6 s
# Wall time: 11.7 s

# %%
# %time dimer.plotFig12(0,U,t,beta,mu,0,-6,6,-6,6,500,1.0)
# Out:
# CPU times: user 11.5 s, sys: 204 ms, total: 11.7 s
# Wall time: 11.7 s
